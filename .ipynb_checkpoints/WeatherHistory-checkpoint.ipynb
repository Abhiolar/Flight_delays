# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from dateutil.parser import parse
import pandas as pd

# %%
df = pd.read_csv('/Users/flatironschool/Downloads/flight_delays/flight_delays.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Month  DayofMonth  Hour Origin Dest  SchedDep  \
# 0           0             7      1           1    22    DFW  MIA    2120.0
# 1           1            18      1           1    22    DFW  LAX    2210.0
# 2           2            19      1           1    22    DFW  ORD    2130.0
# 3           3            21      1           1    22    DFW  ORD    2215.0
# 4           4            49      1           1    18    LAX  ORD    1750.0
#
#    DepTime  DepDelay  ArrTime  ArrDelay  AirTime FlightNumber   Temp  \
# 0   2204.0      84.0    139.0      73.0    136.0       AA2329  65.01
# 1   2216.0       6.0   2353.0       9.0    184.0       AA1023  65.01
# 2   2220.0      90.0     19.0      74.0     98.0       AA1040  65.01
# 3   2208.0      -7.0   2400.0     -30.0     95.0       AA2525  65.01
# 4   1837.0      87.0     21.0      58.0    200.0       AA2576  47.59
#
#    Humidity  Wind  Pressure    Description
# 0      77.0   2.0    1009.0  broken clouds
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84866 entries, 0 to 84865
# Data columns (total 19 columns):
# Unnamed: 0      84866 non-null int64
# Unnamed: 0.1    84866 non-null int64
# Month           84866 non-null int64
# DayofMonth      84866 non-null int64
# Hour            84866 non-null int64
# Origin          84866 non-null object
# Dest            84866 non-null object
# SchedDep        84866 non-null float64
# DepTime         84866 non-null float64
# DepDelay        84866 non-null float64
# ArrTime         84866 non-null float64
# ArrDelay        84866 non-null float64
# AirTime         84866 non-null float64
# FlightNumber    84866 non-null object
# Temp            84866 non-null float64
# Humidity        84862 non-null float64
# Wind            84866 non-null float64
# Pressure        84865 non-null float64
# Description     84866 non-null object
# dtypes: float64(10), int64(5), object(4)
# memory usage: 12.3+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# Month           0
# DayofMonth      0
# Hour            0
# Origin          0
# Dest            0
# SchedDep        0
# DepTime         0
# DepDelay        0
# ArrTime         0
# ArrDelay        0
# AirTime         0
# FlightNumber    0
# Temp            0
# Humidity        4
# Wind            0
# Pressure        1
# Description     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# Month           0
# DayofMonth      0
# Hour            0
# Origin          0
# Dest            0
# SchedDep        0
# DepTime         0
# DepDelay        0
# ArrTime         0
# ArrDelay        0
# AirTime         0
# FlightNumber    0
# Temp            0
# Humidity        0
# Wind            0
# Pressure        0
# Description     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84861 entries, 0 to 84865
# Data columns (total 19 columns):
# Unnamed: 0      84861 non-null int64
# Unnamed: 0.1    84861 non-null int64
# Month           84861 non-null int64
# DayofMonth      84861 non-null int64
# Hour            84861 non-null int64
# Origin          84861 non-null object
# Dest            84861 non-null object
# SchedDep        84861 non-null float64
# DepTime         84861 non-null float64
# DepDelay        84861 non-null float64
# ArrTime         84861 non-null float64
# ArrDelay        84861 non-null float64
# AirTime         84861 non-null float64
# FlightNumber    84861 non-null object
# Temp            84861 non-null float64
# Humidity        84861 non-null float64
# Wind            84861 non-null float64
# Pressure        84861 non-null float64
# Description     84861 non-null object
# dtypes: float64(10), int64(5), object(4)
# memory usage: 12.9+ MB

# %%
del df['Unnamed: 0']

# %%
del df['Unnamed: 0.1']

# %%
df.head()
# Out:
#    Month  DayofMonth  Hour Origin Dest  SchedDep  DepTime  DepDelay  ArrTime  \
# 0      1           1    22    DFW  MIA    2120.0   2204.0      84.0    139.0
# 1      1           1    22    DFW  LAX    2210.0   2216.0       6.0   2353.0
# 2      1           1    22    DFW  ORD    2130.0   2220.0      90.0     19.0
# 3      1           1    22    DFW  ORD    2215.0   2208.0      -7.0   2400.0
# 4      1           1    18    LAX  ORD    1750.0   1837.0      87.0     21.0
#
#    ArrDelay  AirTime FlightNumber   Temp  Humidity  Wind  Pressure  \
# 0      73.0    136.0       AA2329  65.01      77.0   2.0    1009.0
# 1       9.0    184.0       AA1023  65.01      77.0   2.0    1009.0
# 2      74.0     98.0       AA1040  65.01      77.0   2.0    1009.0
# 3     -30.0     95.0       AA2525  65.01      77.0   2.0    1009.0
# 4      58.0    200.0       AA2576  47.59      81.0   3.0    1014.0
#
#      Description
# 0  broken clouds
# 1  broken clouds
# 2  broken clouds
# 3  broken clouds
# ...

# %%
df['DepTime'] = df['DepTime'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84861 entries, 0 to 84865
# Data columns (total 17 columns):
# Month           84861 non-null int64
# DayofMonth      84861 non-null int64
# Hour            84861 non-null int64
# Origin          84861 non-null object
# Dest            84861 non-null object
# SchedDep        84861 non-null float64
# DepTime         84861 non-null int64
# DepDelay        84861 non-null float64
# ArrTime         84861 non-null float64
# ArrDelay        84861 non-null float64
# AirTime         84861 non-null float64
# FlightNumber    84861 non-null object
# Temp            84861 non-null float64
# Humidity        84861 non-null float64
# Wind            84861 non-null float64
# Pressure        84861 non-null float64
# Description     84861 non-null object
# dtypes: float64(9), int64(4), object(4)
# memory usage: 11.7+ MB

# %%
df['DepTime'] = df['DepTime'].astype(str)

# %%
df['DepTime'] = df['DepTime'].apply(lambda x: '{0:0>4}'.format(x))

# %%
df.head(20)
# Out:
#     Month  DayofMonth  Hour Origin Dest  SchedDep DepTime  DepDelay  ArrTime  \
# 0       1           1    22    DFW  MIA    2120.0    2204      84.0    139.0
# 1       1           1    22    DFW  LAX    2210.0    2216       6.0   2353.0
# 2       1           1    22    DFW  ORD    2130.0    2220      90.0     19.0
# 3       1           1    22    DFW  ORD    2215.0    2208      -7.0   2400.0
# 4       1           1    18    LAX  ORD    1750.0    1837      87.0     21.0
# 5       1           1    18    LAX  ORD    1801.0    1841      40.0     16.0
# 6       1           1     9    LAX  ORD     945.0    0957      12.0   1539.0
# 7       1           1     9    LAX  JFK     900.0    0934      34.0   1809.0
# 8       1           1     9    LAX  ORD     945.0    0955      10.0   1553.0
# 9       1           1     9    LAX  DFW     932.0    0930      -2.0   1444.0
# 10      1           1     9    LAX  ORD     905.0    0913       8.0   1504.0
# ...

# %%
df.DepTime = df['DepTime'].apply(lambda x: '{0:0<6}'.format(x))

# %%
df.head()
# Out:
#    Month  DayofMonth  Hour Origin Dest  SchedDep DepTime  DepDelay  ArrTime  \
# 0      1           1    22    DFW  MIA    2120.0  220400      84.0    139.0
# 1      1           1    22    DFW  LAX    2210.0  221600       6.0   2353.0
# 2      1           1    22    DFW  ORD    2130.0  222000      90.0     19.0
# 3      1           1    22    DFW  ORD    2215.0  220800      -7.0   2400.0
# 4      1           1    18    LAX  ORD    1750.0  183700      87.0     21.0
#
#    ArrDelay  AirTime FlightNumber   Temp  Humidity  Wind  Pressure  \
# 0      73.0    136.0       AA2329  65.01      77.0   2.0    1009.0
# 1       9.0    184.0       AA1023  65.01      77.0   2.0    1009.0
# 2      74.0     98.0       AA1040  65.01      77.0   2.0    1009.0
# 3     -30.0     95.0       AA2525  65.01      77.0   2.0    1009.0
# 4      58.0    200.0       AA2576  47.59      81.0   3.0    1014.0
#
#      Description
# 0  broken clouds
# 1  broken clouds
# 2  broken clouds
# 3  broken clouds
# ...

# %%
df['DepTime'] = pd.to_datetime(df['DepTime'],format= '%H%M%S' )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84861 entries, 0 to 84865
# Data columns (total 17 columns):
# Month           84861 non-null int64
# DayofMonth      84861 non-null int64
# Hour            84861 non-null int64
# Origin          84861 non-null object
# Dest            84861 non-null object
# SchedDep        84861 non-null float64
# DepTime         84861 non-null datetime64[ns]
# DepDelay        84861 non-null float64
# ArrTime         84861 non-null float64
# ArrDelay        84861 non-null float64
# AirTime         84861 non-null float64
# FlightNumber    84861 non-null object
# Temp            84861 non-null float64
# Humidity        84861 non-null float64
# Wind            84861 non-null float64
# Pressure        84861 non-null float64
# Description     84861 non-null object
# dtypes: datetime64[ns](1), float64(9), int64(3), object(4)
# memory usage: 11.7+ MB

# %%
df.head()
# Out:
#    Month  DayofMonth  Hour Origin Dest  SchedDep             DepTime  \
# 0      1           1    22    DFW  MIA    2120.0 1900-01-01 22:04:00
# 1      1           1    22    DFW  LAX    2210.0 1900-01-01 22:16:00
# 2      1           1    22    DFW  ORD    2130.0 1900-01-01 22:20:00
# 3      1           1    22    DFW  ORD    2215.0 1900-01-01 22:08:00
# 4      1           1    18    LAX  ORD    1750.0 1900-01-01 18:37:00
#
#    DepDelay  ArrTime  ArrDelay  AirTime FlightNumber   Temp  Humidity  Wind  \
# 0      84.0    139.0      73.0    136.0       AA2329  65.01      77.0   2.0
# 1       6.0   2353.0       9.0    184.0       AA1023  65.01      77.0   2.0
# 2      90.0     19.0      74.0     98.0       AA1040  65.01      77.0   2.0
# 3      -7.0   2400.0     -30.0     95.0       AA2525  65.01      77.0   2.0
# 4      87.0     21.0      58.0    200.0       AA2576  47.59      81.0   3.0
#
#    Pressure    Description
# 0    1009.0  broken clouds
# 1    1009.0  broken clouds
# ...

# %%
df['DepTime'] = pd.Series([val.time() for val in df['DepTime']])

# %%
df.head()
# Out:
#    Month  DayofMonth  Hour Origin Dest  SchedDep   DepTime  DepDelay  ArrTime  \
# 0      1           1    22    DFW  MIA    2120.0  22:04:00      84.0    139.0
# 1      1           1    22    DFW  LAX    2210.0  22:16:00       6.0   2353.0
# 2      1           1    22    DFW  ORD    2130.0  22:20:00      90.0     19.0
# 3      1           1    22    DFW  ORD    2215.0  22:08:00      -7.0   2400.0
# 4      1           1    18    LAX  ORD    1750.0  18:37:00      87.0     21.0
#
#    ArrDelay  AirTime FlightNumber   Temp  Humidity  Wind  Pressure  \
# 0      73.0    136.0       AA2329  65.01      77.0   2.0    1009.0
# 1       9.0    184.0       AA1023  65.01      77.0   2.0    1009.0
# 2      74.0     98.0       AA1040  65.01      77.0   2.0    1009.0
# 3     -30.0     95.0       AA2525  65.01      77.0   2.0    1009.0
# 4      58.0    200.0       AA2576  47.59      81.0   3.0    1014.0
#
#      Description
# 0  broken clouds
# 1  broken clouds
# 2  broken clouds
# 3  broken clouds
# ...

# %%
df['SchedDep'] = df['SchedDep'].astype(int)

# %%
df['SchedDep'] = df['SchedDep'].astype(str)

# %%
df.SchedDep.value_counts()
# Out:
# 660     1789
# 560     1655
# 1215    1114
# 760     1013
# 1530     767
#         ...
# 2154       1
# -195       1
# 2338       1
# 1796       1
# -255       1
# Name: SchedDep, Length: 1480, dtype: int64

# %%
minus = df[df['SchedDep'].str.contains("-")].index

# %%
df.drop(minus, inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#        Month  DayofMonth  Hour Origin Dest SchedDep   DepTime  DepDelay  \
# 0          1           1    22    DFW  MIA     2120  22:04:00      84.0
# 1          1           1    22    DFW  LAX     2210  22:16:00       6.0
# 2          1           1    22    DFW  ORD     2130  22:20:00      90.0
# 3          1           1    22    DFW  ORD     2215  22:08:00      -7.0
# 4          1           1    18    LAX  ORD     1750  18:37:00      87.0
# ...      ...         ...   ...    ...  ...      ...       ...       ...
# 84192     10          27    22    JFK  LAX     2245       NaN      -9.0
# 84193     10          28     0    LAX  MIA       30       NaN      -6.0
# 84194     10          28     0    LAX  DFW       45       NaN      -2.0
# 84195     10          28     0    LAX  ORD       32       NaN      -6.0
# 84196     10          28     0    LAX  JFK       25       NaN     -10.0
#
#        ArrTime  ArrDelay  AirTime FlightNumber   Temp  Humidity  Wind  \
# ...

# %%
df['SchedDep'] = df['SchedDep'].apply(lambda x: '{0:0>4}'.format(x))

# %%
df.SchedDep = df['SchedDep'].apply(lambda x: '{0:0<6}'.format(x))

# %%
df.SchedDep = df.SchedDep.str[-6:]
df.SchedDep
# Out:
# 0        212000
# 1        221000
# 2        213000
# 3        221500
# 4        175000
#           ...
# 84861    224500
# 84862    003000
# 84863    004500
# 84864    003200
# 84865    002500
# Name: SchedDep, Length: 84197, dtype: object

# %%
df=df[(df.SchedDep.apply(lambda x: len(str(x))==6))]

# %%
df.head()
# Out:
#    Month  DayofMonth  Hour Origin Dest SchedDep   DepTime  DepDelay  ArrTime  \
# 0      1           1    22    DFW  MIA   212000  22:04:00      84.0    139.0
# 1      1           1    22    DFW  LAX   221000  22:16:00       6.0   2353.0
# 2      1           1    22    DFW  ORD   213000  22:20:00      90.0     19.0
# 3      1           1    22    DFW  ORD   221500  22:08:00      -7.0   2400.0
# 4      1           1    18    LAX  ORD   175000  18:37:00      87.0     21.0
#
#    ArrDelay  AirTime FlightNumber   Temp  Humidity  Wind  Pressure  \
# 0      73.0    136.0       AA2329  65.01      77.0   2.0    1009.0
# 1       9.0    184.0       AA1023  65.01      77.0   2.0    1009.0
# 2      74.0     98.0       AA1040  65.01      77.0   2.0    1009.0
# 3     -30.0     95.0       AA2525  65.01      77.0   2.0    1009.0
# 4      58.0    200.0       AA2576  47.59      81.0   3.0    1014.0
#
#      Description
# 0  broken clouds
# 1  broken clouds
# 2  broken clouds
# 3  broken clouds
# ...

# %%
df.SchedDep.str.len().value_counts()
# Out:
# 6    84197
# Name: SchedDep, dtype: int64

# %%
pd.to_datetime(df['SchedDep'],format= '%H%M%S')
# Out:
# 0   1900-01-01 21:20:00
# Name: SchedDep, dtype: datetime64[ns]

# %%
a=[]
for i in df.SchedDep:
    timex= pd.to_datetime(i,format= '%H%M%S')
    a.append(timex)
    print(a)
# Out:
# [Timestamp('1900-01-01 21:20:00')]
# [Timestamp('1900-01-01 21:20:00'), Timestamp('1900-01-01 22:10:00')]
# [Timestamp('1900-01-01 21:20:00'), Timestamp('1900-01-01 22:10:00'), Timestamp('1900-01-01 21:30:00')]
# [Timestamp('1900-01-01 21:20:00'), Timestamp('1900-01-01 22:10:00'), Timestamp('1900-01-01 21:30:00'), Timestamp('1900-01-01 22:15:00')]
# [Timestamp('1900-01-01 21:20:00'), Timestamp('1900-01-01 22:10:00'), Timestamp('1900-01-01 21:30:00'), Timestamp('1900-01-01 22:15:00'), Timestamp('1900-01-01 17:50:00')]
# [Timestamp('1900-01-01 21:20:00'), Timestamp('1900-01-01 22:10:00'), Timestamp('1900-01-01 21:30:00'), Timestamp('1900-01-01 22:15:00'), Timestamp('1900-01-01 17:50:00'), Timestamp('1900-01-01 18:01:00')]
# [Timestamp('1900-01-01 21:20:00'), Timestamp('1900-01-01 22:10:00'), Timestamp('1900-01-01 21:30:00'), Timestamp('1900-01-01 22:15:00'), Timestamp('1900-01-01 17:50:00'), Timestamp('1900-01-01 18:01:00'), Timestamp('1900-01-01 09:45:00')]
# ...

# %%
df[df['SchedDep'].str.contains("20:35:00")].index
# Out:
# Int64Index([], dtype='int64')

# %%
df.loc[df['SchedDep'] == '203500'].index[0]
# Out:
# 14

# %%
df.head(16)
# Out:
#     Month  DayofMonth  Hour Origin Dest SchedDep   DepTime  DepDelay  ArrTime  \
# 0       1           1    22    DFW  MIA   212000  22:04:00      84.0    139.0
# 1       1           1    22    DFW  LAX   221000  22:16:00       6.0   2353.0
# 2       1           1    22    DFW  ORD   213000  22:20:00      90.0     19.0
# 3       1           1    22    DFW  ORD   221500  22:08:00      -7.0   2400.0
# 4       1           1    18    LAX  ORD   175000  18:37:00      87.0     21.0
# 5       1           1    18    LAX  ORD   180100  18:41:00      40.0     16.0
# 6       1           1     9    LAX  ORD   094500  09:57:00      12.0   1539.0
# 7       1           1     9    LAX  JFK   090000  09:34:00      34.0   1809.0
# 8       1           1     9    LAX  ORD   094500  09:55:00      10.0   1553.0
# 9       1           1     9    LAX  DFW   093200  09:30:00      -2.0   1444.0
# 10      1           1     9    LAX  ORD   090500  09:13:00       8.0   1504.0
# ...

# %%
df['SchedDep'] = df['SchedDep'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84197 entries, 0 to 84865
# Data columns (total 17 columns):
# Month           84197 non-null int64
# DayofMonth      84197 non-null int64
# Hour            84197 non-null int64
# Origin          84197 non-null object
# Dest            84197 non-null object
# SchedDep        84197 non-null object
# DepTime         84192 non-null object
# DepDelay        84197 non-null float64
# ArrTime         84197 non-null float64
# ArrDelay        84197 non-null float64
# AirTime         84197 non-null float64
# FlightNumber    84197 non-null object
# Temp            84197 non-null float64
# Humidity        84197 non-null float64
# Wind            84197 non-null float64
# Pressure        84197 non-null float64
# Description     84197 non-null object
# dtypes: float64(8), int64(3), object(6)
# memory usage: 11.6+ MB

# %%
df.SchedDep.str[2]
# Out:
# 0        2
# 1        1
# 2        3
# 3        1
# 4        5
#         ..
# 84861    4
# 84862    3
# 84863    4
# 84864    3
# 84865    2
# Name: SchedDep, Length: 84197, dtype: object

# %%
a =[]
for j, i in enumerate (df.SchedDep.str[2]):
    if i == '6':
        a.append(j)
    if i == '7':
        a.append(j)
    if i == '8':
        a.append(j)
    if i == '9':
        a.append(j)

# %%
len(a)
# Out:
# 18017

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84197 entries, 0 to 84865
# Data columns (total 17 columns):
# Month           84197 non-null int64
# DayofMonth      84197 non-null int64
# Hour            84197 non-null int64
# Origin          84197 non-null object
# Dest            84197 non-null object
# SchedDep        84197 non-null object
# DepTime         84192 non-null object
# DepDelay        84197 non-null float64
# ArrTime         84197 non-null float64
# ArrDelay        84197 non-null float64
# AirTime         84197 non-null float64
# FlightNumber    84197 non-null object
# Temp            84197 non-null float64
# Humidity        84197 non-null float64
# Wind            84197 non-null float64
# Pressure        84197 non-null float64
# Description     84197 non-null object
# dtypes: float64(8), int64(3), object(6)
# memory usage: 11.6+ MB

# %%
ddp = df.index[a]

# %%
df = df.drop(index=ddp,axis =1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-8f3da496f969> in <module>
# ----> 1 df = df.drop(index=ddp,axis =1, inplace=True)
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66180 entries, 0 to 84865
# Data columns (total 17 columns):
# Month           66180 non-null int64
# DayofMonth      66180 non-null int64
# Hour            66180 non-null int64
# Origin          66180 non-null object
# Dest            66180 non-null object
# SchedDep        66180 non-null object
# DepTime         66175 non-null object
# DepDelay        66180 non-null float64
# ArrTime         66180 non-null float64
# ArrDelay        66180 non-null float64
# AirTime         66180 non-null float64
# FlightNumber    66180 non-null object
# Temp            66180 non-null float64
# Humidity        66180 non-null float64
# Wind            66180 non-null float64
# Pressure        66180 non-null float64
# Description     66180 non-null object
# dtypes: float64(8), int64(3), object(6)
# memory usage: 11.6+ MB

# %%
df.SchedDep= pd.to_datetime(df['SchedDep'],format= '%H:%M:%S')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66180 entries, 0 to 84865
# Data columns (total 17 columns):
# Month           66180 non-null int64
# DayofMonth      66180 non-null int64
# Hour            66180 non-null int64
# Origin          66180 non-null object
# Dest            66180 non-null object
# SchedDep        66180 non-null datetime64[ns]
# DepTime         66175 non-null object
# DepDelay        66180 non-null float64
# ArrTime         66180 non-null float64
# ArrDelay        66180 non-null float64
# AirTime         66180 non-null float64
# FlightNumber    66180 non-null object
# Temp            66180 non-null float64
# Humidity        66180 non-null float64
# Wind            66180 non-null float64
# Pressure        66180 non-null float64
# Description     66180 non-null object
# dtypes: datetime64[ns](1), float64(8), int64(3), object(5)
# memory usage: 11.6+ MB

# %%
df.head()
# Out:
#    Month  DayofMonth  Hour Origin Dest            SchedDep   DepTime  \
# 0      1           1    22    DFW  MIA 1900-01-01 21:20:00  22:04:00
# 1      1           1    22    DFW  LAX 1900-01-01 22:10:00  22:16:00
# 2      1           1    22    DFW  ORD 1900-01-01 21:30:00  22:20:00
# 3      1           1    22    DFW  ORD 1900-01-01 22:15:00  22:08:00
# 4      1           1    18    LAX  ORD 1900-01-01 17:50:00  18:37:00
#
#    DepDelay  ArrTime  ArrDelay  AirTime FlightNumber   Temp  Humidity  Wind  \
# 0      84.0    139.0      73.0    136.0       AA2329  65.01      77.0   2.0
# 1       6.0   2353.0       9.0    184.0       AA1023  65.01      77.0   2.0
# 2      90.0     19.0      74.0     98.0       AA1040  65.01      77.0   2.0
# 3      -7.0   2400.0     -30.0     95.0       AA2525  65.01      77.0   2.0
# 4      87.0     21.0      58.0    200.0       AA2576  47.59      81.0   3.0
#
#    Pressure    Description
# 0    1009.0  broken clouds
# 1    1009.0  broken clouds
# ...

# %%
df['SchedDep'] = pd.Series([val.time() for val in df['SchedDep']])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66180 entries, 0 to 84865
# Data columns (total 17 columns):
# Month           66180 non-null int64
# DayofMonth      66180 non-null int64
# Hour            66180 non-null int64
# Origin          66180 non-null object
# Dest            66180 non-null object
# SchedDep        51404 non-null object
# DepTime         66175 non-null object
# DepDelay        66180 non-null float64
# ArrTime         66180 non-null float64
# ArrDelay        66180 non-null float64
# AirTime         66180 non-null float64
# FlightNumber    66180 non-null object
# Temp            66180 non-null float64
# Humidity        66180 non-null float64
# Wind            66180 non-null float64
# Pressure        66180 non-null float64
# Description     66180 non-null object
# dtypes: float64(8), int64(3), object(6)
# memory usage: 11.6+ MB

# %%
df.DepTime= pd.to_datetime(df['DepTime'],format= '%H:%M:%S')

# %%
df.SchedDep= pd.to_datetime(df['SchedDep'],format= '%H:%M:%S')

# %%
df['Delay_min'] = (df['DepTime'] - df['SchedDep']).dt.seconds/60

# %%
df.head()
# Out:
#    Month  DayofMonth  Hour Origin Dest            SchedDep  \
# 0      1           1    22    DFW  MIA 1900-01-01 21:20:00
# 1      1           1    22    DFW  LAX 1900-01-01 22:10:00
# 2      1           1    22    DFW  ORD 1900-01-01 21:30:00
# 3      1           1    22    DFW  ORD 1900-01-01 22:15:00
# 4      1           1    18    LAX  ORD 1900-01-01 17:50:00
#
#               DepTime  DepDelay  ArrTime  ArrDelay  AirTime FlightNumber  \
# 0 1900-01-01 22:04:00      84.0    139.0      73.0    136.0       AA2329
# 1 1900-01-01 22:16:00       6.0   2353.0       9.0    184.0       AA1023
# 2 1900-01-01 22:20:00      90.0     19.0      74.0     98.0       AA1040
# 3 1900-01-01 22:08:00      -7.0   2400.0     -30.0     95.0       AA2525
# 4 1900-01-01 18:37:00      87.0     21.0      58.0    200.0       AA2576
#
#     Temp  Humidity  Wind  Pressure    Description  Difference  Delay_min
# 0  65.01      77.0   2.0    1009.0  broken clouds        44.0       44.0
# ...

# %%
df.corr()
# Out:
#                Month  DayofMonth      Hour  DepDelay   ArrTime  ArrDelay  \
# Month       1.000000   -0.015237  0.013013 -0.023012 -0.006746 -0.021540
# DayofMonth -0.015237    1.000000 -0.000209 -0.019401 -0.001348 -0.022907
# Hour        0.013013   -0.000209  1.000000  0.125619  0.193614  0.105412
# DepDelay   -0.023012   -0.019401  0.125619  1.000000 -0.020411  0.921155
# ArrTime    -0.006746   -0.001348  0.193614 -0.020411  1.000000 -0.017324
# ArrDelay   -0.021540   -0.022907  0.105412  0.921155 -0.017324  1.000000
# AirTime    -0.011686   -0.003865  0.035982  0.021688 -0.038889  0.035785
# Temp        0.541680    0.057572  0.210621  0.025830 -0.038885  0.032528
# Humidity   -0.065682   -0.008947 -0.353273 -0.014603  0.013304 -0.008624
# Wind       -0.156282    0.003257  0.239275  0.041354 -0.007182  0.054609
# Pressure   -0.031801   -0.100276  0.024344 -0.019178  0.044226 -0.033638
# Difference -0.000263   -0.002543 -0.224464 -0.031331 -0.079503 -0.029048
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66180 entries, 0 to 84865
# Data columns (total 19 columns):
# Month           66180 non-null int64
# DayofMonth      66180 non-null int64
# Hour            66180 non-null int64
# Origin          66180 non-null object
# Dest            66180 non-null object
# SchedDep        51404 non-null datetime64[ns]
# DepTime         66175 non-null datetime64[ns]
# DepDelay        66180 non-null float64
# ArrTime         66180 non-null float64
# ArrDelay        66180 non-null float64
# AirTime         66180 non-null float64
# FlightNumber    66180 non-null object
# Temp            66180 non-null float64
# Humidity        66180 non-null float64
# Wind            66180 non-null float64
# Pressure        66180 non-null float64
# Description     66180 non-null object
# Difference      51404 non-null float64
# Delay_min       51404 non-null float64
# dtypes: datetime64[ns](2), float64(10), int64(3), object(4)
# memory usage: 12.6+ MB

# %%
Dep_minus = df[df['DepDelay'].astype(str).str.contains("-")].index

# %%
df.drop(Dep_minus, inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#        Month  DayofMonth  Hour Origin Dest            SchedDep  \
# 0          1           1    22    DFW  MIA 1900-01-01 21:20:00
# 1          1           1    22    DFW  LAX 1900-01-01 22:10:00
# 2          1           1    22    DFW  ORD 1900-01-01 21:30:00
# 3          1           1    18    LAX  ORD 1900-01-01 17:50:00
# 4          1           1    18    LAX  ORD 1900-01-01 18:01:00
# ...      ...         ...   ...    ...  ...                 ...
# 29835     10          27     7    DFW  LAX                 NaT
# 29836     10          27     7    DFW  ORD                 NaT
# 29837     10          27    21    MIA  ORD                 NaT
# 29838     10          27    22    DFW  ORD                 NaT
# 29839     10          27     1    LAX  ORD                 NaT
#
#                   DepTime  DepDelay  ArrTime  ArrDelay  AirTime FlightNumber  \
# 0     1900-01-01 22:04:00      84.0    139.0      73.0    136.0       AA2329
# ...

# %%
df.isnull().sum()
# Out:
# Month              0
# DayofMonth         0
# Hour               0
# Origin             0
# Dest               0
# SchedDep        5507
# DepTime            0
# DepDelay           0
# ArrTime            0
# ArrDelay           0
# AirTime            0
# FlightNumber       0
# Temp               0
# Humidity           0
# Wind               0
# Pressure           0
# Description        0
# Difference      5507
# Delay_min       5507
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24333 entries, 0 to 66179
# Data columns (total 19 columns):
# Month           24333 non-null int64
# DayofMonth      24333 non-null int64
# Hour            24333 non-null int64
# Origin          24333 non-null object
# Dest            24333 non-null object
# SchedDep        24333 non-null datetime64[ns]
# DepTime         24333 non-null datetime64[ns]
# DepDelay        24333 non-null float64
# ArrTime         24333 non-null float64
# ArrDelay        24333 non-null float64
# AirTime         24333 non-null float64
# FlightNumber    24333 non-null object
# Temp            24333 non-null float64
# Humidity        24333 non-null float64
# Wind            24333 non-null float64
# Pressure        24333 non-null float64
# Description     24333 non-null object
# Difference      24333 non-null float64
# Delay_min       24333 non-null float64
# dtypes: datetime64[ns](2), float64(10), int64(3), object(4)
# memory usage: 3.7+ MB

# %%
df.head()
# Out:
#    Month  DayofMonth  Hour Origin Dest            SchedDep  \
# 0      1           1    22    DFW  MIA 1900-01-01 21:20:00
# 1      1           1    22    DFW  LAX 1900-01-01 22:10:00
# 2      1           1    22    DFW  ORD 1900-01-01 21:30:00
# 4      1           1    18    LAX  ORD 1900-01-01 17:50:00
# 5      1           1    18    LAX  ORD 1900-01-01 18:01:00
#
#               DepTime  DepDelay  ArrTime  ArrDelay  AirTime FlightNumber  \
# 0 1900-01-01 22:04:00      84.0    139.0      73.0    136.0       AA2329
# 1 1900-01-01 22:16:00       6.0   2353.0       9.0    184.0       AA1023
# 2 1900-01-01 22:20:00      90.0     19.0      74.0     98.0       AA1040
# 4 1900-01-01 18:37:00      87.0     21.0      58.0    200.0       AA2576
# 5 1900-01-01 18:41:00      40.0     16.0      12.0    198.0        UA342
#
#     Temp  Humidity  Wind  Pressure    Description  Difference  Delay_min
# 0  65.01      77.0   2.0    1009.0  broken clouds        44.0       44.0
# ...

# %%
df['SchedDep'] = pd.Series([val.time() for val in df['SchedDep']])

# %%
df['DepTime'] = pd.Series([val.time() for val in df['DepTime']])

# %%
df.head()
# Out:
#    Month  DayofMonth  Hour Origin Dest  SchedDep   DepTime  DepDelay  ArrTime  \
# 0      1           1    22    DFW  MIA  21:20:00  22:04:00      84.0    139.0
# 1      1           1    22    DFW  LAX  22:10:00  22:16:00       6.0   2353.0
# 2      1           1    22    DFW  ORD  21:30:00  22:20:00      90.0     19.0
# 4      1           1    18    LAX  ORD  18:01:00  18:41:00      87.0     21.0
# 5      1           1    18    LAX  ORD  09:45:00  09:57:00      40.0     16.0
#
#    ArrDelay  AirTime FlightNumber   Temp  Humidity  Wind  Pressure  \
# 0      73.0    136.0       AA2329  65.01      77.0   2.0    1009.0
# 1       9.0    184.0       AA1023  65.01      77.0   2.0    1009.0
# 2      74.0     98.0       AA1040  65.01      77.0   2.0    1009.0
# 4      58.0    200.0       AA2576  47.59      81.0   3.0    1014.0
# 5      12.0    198.0        UA342  47.59      81.0   3.0    1014.0
#
#      Description  Difference  Delay_min
# 0  broken clouds        44.0       44.0
# ...

# %%
df.to_csv('Flight Data', encoding = 'utf-8', index = False)
