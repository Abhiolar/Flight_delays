# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from dateutil.parser import parse
import pandas as pd

# %% [markdown]
# This notebook entails a step by step process of cleaning the flights delay dataset to prepare the data for exploratory data analysis.

# %%
df = pd.read_csv('flight_delays.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Month  DayofMonth  Hour Origin Dest  SchedDep  \
# 0           0             7      1           1    22    DFW  MIA    2120.0
# 1           1            18      1           1    22    DFW  LAX    2210.0
# 2           2            19      1           1    22    DFW  ORD    2130.0
# 3           3            21      1           1    22    DFW  ORD    2215.0
# 4           4            49      1           1    18    LAX  ORD    1750.0
#
#    DepTime  DepDelay  ArrTime  ArrDelay  AirTime FlightNumber   Temp  \
# 0   2204.0      84.0    139.0      73.0    136.0       AA2329  65.01
# 1   2216.0       6.0   2353.0       9.0    184.0       AA1023  65.01
# 2   2220.0      90.0     19.0      74.0     98.0       AA1040  65.01
# 3   2208.0      -7.0   2400.0     -30.0     95.0       AA2525  65.01
# 4   1837.0      87.0     21.0      58.0    200.0       AA2576  47.59
#
#    Humidity  Wind  Pressure    Description
# 0      77.0   2.0    1009.0  broken clouds
# 1      77.0   2.0    1009.0  broken clouds
# 2      77.0   2.0    1009.0  broken clouds
# 3      77.0   2.0    1009.0  broken clouds
# 4      81.0   3.0    1014.0            fog

# %% [markdown]
# The data frame has some unnamed columns, the first step is to drop these columns since we are not sure of the data they contain and get the summary info of the overall dataframe

# %%
del df['Unnamed: 0']

# %%
del df['Unnamed: 0.1']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84866 entries, 0 to 84865
# Data columns (total 17 columns):
# Month           84866 non-null int64
# DayofMonth      84866 non-null int64
# Hour            84866 non-null int64
# Origin          84866 non-null object
# Dest            84866 non-null object
# SchedDep        84866 non-null float64
# DepTime         84866 non-null float64
# DepDelay        84866 non-null float64
# ArrTime         84866 non-null float64
# ArrDelay        84866 non-null float64
# AirTime         84866 non-null float64
# FlightNumber    84866 non-null object
# Temp            84866 non-null float64
# Humidity        84862 non-null float64
# Wind            84866 non-null float64
# Pressure        84865 non-null float64
# Description     84866 non-null object
# dtypes: float64(10), int64(3), object(4)
# memory usage: 11.0+ MB

# %% [markdown]
# The ovearll dataset contains 84,866 data points with 17 columns including the index

# %%
df.head()
# Out:
#    Month  DayofMonth  Hour Origin Dest  SchedDep  DepTime  DepDelay  ArrTime  \
# 0      1           1    22    DFW  MIA    2120.0   2204.0      84.0    139.0
# 1      1           1    22    DFW  LAX    2210.0   2216.0       6.0   2353.0
# 2      1           1    22    DFW  ORD    2130.0   2220.0      90.0     19.0
# 3      1           1    22    DFW  ORD    2215.0   2208.0      -7.0   2400.0
# 4      1           1    18    LAX  ORD    1750.0   1837.0      87.0     21.0
#
#    ArrDelay  AirTime FlightNumber   Temp  Humidity  Wind  Pressure  \
# 0      73.0    136.0       AA2329  65.01      77.0   2.0    1009.0
# 1       9.0    184.0       AA1023  65.01      77.0   2.0    1009.0
# 2      74.0     98.0       AA1040  65.01      77.0   2.0    1009.0
# 3     -30.0     95.0       AA2525  65.01      77.0   2.0    1009.0
# 4      58.0    200.0       AA2576  47.59      81.0   3.0    1014.0
#
#      Description
# 0  broken clouds
# 1  broken clouds
# 2  broken clouds
# 3  broken clouds
# 4            fog

# %% [markdown]
# The project's aim is to be able to predict the length of delay for each delayed flight which is the difference between the Scheduled Departure time and the Actual departure time

# %% [markdown]
# Checking the data for null values and duplicated data

# %%
df.isna().sum()
# Out:
# Month           0
# DayofMonth      0
# Hour            0
# Origin          0
# Dest            0
# SchedDep        0
# DepTime         0
# DepDelay        0
# ArrTime         0
# ArrDelay        0
# AirTime         0
# FlightNumber    0
# Temp            0
# Humidity        4
# Wind            0
# Pressure        1
# Description     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Dropping the null values of the dataset...

# %%
df.dropna(inplace=True)

# %% [markdown]
# The next step is to change both Departure times we are interested in to datetime objects and subtract the difference in minutes

# %%
df['DepTime'] = df['DepTime'].astype(int)

# %%
df['SchedDep'] = df['SchedDep'].astype(int)

# %%
df['DepTime'] = df['DepTime'].astype(str)

# %%
df['SchedDep'] = df['SchedDep'].astype(str)

# %%
df['DepTime'] = df['DepTime'].apply(lambda x: '{0:0>4}'.format(x))#adding zeros to the front to convert it to datetime fromat

# %%
df['SchedDep'] = df['SchedDep'].apply(lambda x: '{0:0>4}'.format(x))

# %%
df.head(15)
# Out:
#     Month  DayofMonth  Hour Origin Dest SchedDep DepTime  DepDelay  ArrTime  \
# 0       1           1    22    DFW  MIA     2120    2204      84.0    139.0
# 1       1           1    22    DFW  LAX     2210    2216       6.0   2353.0
# 2       1           1    22    DFW  ORD     2130    2220      90.0     19.0
# 3       1           1    22    DFW  ORD     2215    2208      -7.0   2400.0
# 4       1           1    18    LAX  ORD     1750    1837      87.0     21.0
# 5       1           1    18    LAX  ORD     1801    1841      40.0     16.0
# 6       1           1     9    LAX  ORD     0945    0957      12.0   1539.0
# 7       1           1     9    LAX  JFK     0900    0934      34.0   1809.0
# 8       1           1     9    LAX  ORD     0945    0955      10.0   1553.0
# 9       1           1     9    LAX  DFW     0932    0930      -2.0   1444.0
# 10      1           1     9    LAX  ORD     0905    0913       8.0   1504.0
# 11      1           1    10    DFW  MIA     1025    1023      -2.0   1345.0
# 12      1           1    10    DFW  LAX     1010    1007      -3.0   1201.0
# 13      1           1    20    DFW  LAX     1955    2045      90.0   2220.0
# 14      1           1    20    DFW  ORD     2035    2033      -2.0   2238.0
#
#     ArrDelay  AirTime FlightNumber   Temp  Humidity  Wind  Pressure  \
# 0       73.0    136.0       AA2329  65.01      77.0   2.0    1009.0
# 1        9.0    184.0       AA1023  65.01      77.0   2.0    1009.0
# 2       74.0     98.0       AA1040  65.01      77.0   2.0    1009.0
# 3      -30.0     95.0       AA2525  65.01      77.0   2.0    1009.0
# 4       58.0    200.0       AA2576  47.59      81.0   3.0    1014.0
# 5       12.0    198.0        UA342  47.59      81.0   3.0    1014.0
# 6      -10.0    202.0        NK730  45.48      87.0   0.0    1012.0
# 7       42.0    289.0          AA2  45.48      87.0   0.0    1012.0
# 8       -6.0    206.0        AA110  45.48      87.0   0.0    1012.0
# 9       -4.0    160.0       OO5614  45.48      87.0   0.0    1012.0
# 10       3.0    202.0       UA2039  45.48      87.0   0.0    1012.0
# 11     -23.0    128.0       AA2307  45.61      61.0   1.0    1011.0
# 12      17.0    169.0        AA937  45.61      61.0   1.0    1011.0
# 13      90.0    178.0       AA2477  59.68      93.0   1.0    1011.0
# 14     -15.0    100.0       AA1142  59.68      93.0   1.0    1011.0
#
#       Description
# 0   broken clouds
# 1   broken clouds
# 2   broken clouds
# 3   broken clouds
# 4             fog
# 5             fog
# 6    sky is clear
# 7    sky is clear
# 8    sky is clear
# 9    sky is clear
# 10   sky is clear
# 11           haze
# 12           haze
# 13           mist
# 14           mist

# %% [markdown]
# Removing negative values in the Scheduled departure time

# %%
minus = df[df['SchedDep'].str.contains("-")].index

# %%
df.drop(minus, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84197 entries, 0 to 84865
# Data columns (total 17 columns):
# Month           84197 non-null int64
# DayofMonth      84197 non-null int64
# Hour            84197 non-null int64
# Origin          84197 non-null object
# Dest            84197 non-null object
# SchedDep        84197 non-null object
# DepTime         84197 non-null object
# DepDelay        84197 non-null float64
# ArrTime         84197 non-null float64
# ArrDelay        84197 non-null float64
# AirTime         84197 non-null float64
# FlightNumber    84197 non-null object
# Temp            84197 non-null float64
# Humidity        84197 non-null float64
# Wind            84197 non-null float64
# Pressure        84197 non-null float64
# Description     84197 non-null object
# dtypes: float64(8), int64(3), object(6)
# memory usage: 11.6+ MB

# %% [markdown]
# resetting the index

# %%
df.reset_index(drop=True)
# Out:
#        Month  DayofMonth  Hour Origin Dest SchedDep DepTime  DepDelay  \
# 0          1           1    22    DFW  MIA     2120    2204      84.0
# 1          1           1    22    DFW  LAX     2210    2216       6.0
# 2          1           1    22    DFW  ORD     2130    2220      90.0
# 3          1           1    22    DFW  ORD     2215    2208      -7.0
# 4          1           1    18    LAX  ORD     1750    1837      87.0
# 5          1           1    18    LAX  ORD     1801    1841      40.0
# 6          1           1     9    LAX  ORD     0945    0957      12.0
# 7          1           1     9    LAX  JFK     0900    0934      34.0
# 8          1           1     9    LAX  ORD     0945    0955      10.0
# 9          1           1     9    LAX  DFW     0932    0930      -2.0
# 10         1           1     9    LAX  ORD     0905    0913       8.0
# 11         1           1    10    DFW  MIA     1025    1023      -2.0
# 12         1           1    10    DFW  LAX     1010    1007      -3.0
# 13         1           1    20    DFW  LAX     1955    2045      90.0
# 14         1           1    20    DFW  ORD     2035    2033      -2.0
# 15         1           1    17    ORD  MIA     1680    1748      68.0
# 16         1           1    17    ORD  JFK     1750    1747      -3.0
# 17         1           1    17    ORD  LAX     1700    1718      18.0
# 18         1           1     9    DFW  MIA     0905    0906       1.0
# 19         1           1     9    DFW  LAX     0905    0902      -3.0
# 20         1           1     9    DFW  ORD     0905    0920      15.0
# 21         1           1    17    LAX  DFW     1730    1758      28.0
# 22         1           1    17    LAX  ORD     1757    1754      -3.0
# 23         1           1    17    LAX  DFW     1720    1738      18.0
# 24         1           1    17    LAX  DFW     1630    1753     123.0
# 25         1           1    17    LAX  DFW     1670    1747      77.0
# 26         1           1    17    LAX  ORD     1725    1720      -5.0
# 27         1           1    17    LAX  ORD     1725    1719      -6.0
# 28         1           1    12    DFW  ORD     1215    1232      17.0
# 5        1014.0              fog
# 6        1012.0     sky is clear
# 7        1012.0     sky is clear
# 8        1012.0     sky is clear
# 9        1012.0     sky is clear
# 10       1012.0     sky is clear
# 11       1011.0             haze
# 12       1011.0             haze
# 13       1011.0             mist
# 14       1011.0             mist
# 15       1021.0             haze
# 16       1021.0             haze
# 17       1021.0             haze
# 18       1012.0             haze
# 19       1012.0             haze
# 20       1012.0             haze
# 21       1014.0              fog
# 22       1014.0              fog
# 23       1014.0              fog
# 24       1014.0              fog
# 25       1014.0              fog
# 26       1014.0              fog
# 27       1014.0              fog
# 28       1012.0              fog
# 29       1012.0              fog
# ...         ...              ...
# 84167    1021.0    broken clouds
# 84168    1021.0    broken clouds
# 84169    1021.0    broken clouds
# 84170    1021.0    broken clouds
# 84171    1021.0    broken clouds
# 84172    1021.0    broken clouds
# 84173    1011.0  overcast clouds
# 84174    1011.0  overcast clouds
# 84175    1011.0  overcast clouds
# 84176    1009.0       light rain
# 84177    1009.0       light rain
# 84178    1009.0       light rain
# 84179    1018.0     sky is clear
# 84180    1014.0     sky is clear
# 84181    1014.0     sky is clear
# 84182    1015.0    broken clouds
# 84183    1015.0    broken clouds
# 84184    1015.0    broken clouds
# 84185    1015.0    broken clouds
# 84186    1020.0    broken clouds
# 84187    1020.0    broken clouds
# 84188    1019.0     sky is clear
# 84189    1019.0     sky is clear
# 84190    1011.0     sky is clear
# 84191    1019.0     sky is clear
# 84192    1019.0     sky is clear
# 84193    1011.0     sky is clear
# 84194    1011.0     sky is clear
# 84195    1011.0     sky is clear
# 84196    1011.0     sky is clear
#
# [84197 rows x 17 columns]

# %%
df.DepTime = df['DepTime'].apply(lambda x: '{0:0<6}'.format(x))#adding zeros to the back of the values

# %%
df.SchedDep = df['SchedDep'].apply(lambda x: '{0:0<6}'.format(x))

# %% [markdown]
# some of the values in Departure time column has wrong minutes, as some of them are above 60 minutes, we are dropping the values so we can convert the column to datetime

# %%
defect =[]
for j, i in enumerate (df.SchedDep.str[2]):
    if i == '6':
        defect.append(j)
    if i == '7':
        defect.append(j)
    if i == '8':
        defect.append(j)
    if i == '9':
        defect.append(j)

# %%
len(defect)
# Out:
# 18017

# %%
df_defect = df.index[defect]

# %%
df.drop(index=df_defect,axis =1, inplace=True)

# %%
df.head()
# Out:
#    Month  DayofMonth  Hour Origin Dest SchedDep DepTime  DepDelay  ArrTime  \
# 0      1           1    22    DFW  MIA   212000  220400      84.0    139.0
# 1      1           1    22    DFW  LAX   221000  221600       6.0   2353.0
# 2      1           1    22    DFW  ORD   213000  222000      90.0     19.0
# 3      1           1    22    DFW  ORD   221500  220800      -7.0   2400.0
# 4      1           1    18    LAX  ORD   175000  183700      87.0     21.0
#
#    ArrDelay  AirTime FlightNumber   Temp  Humidity  Wind  Pressure  \
# 0      73.0    136.0       AA2329  65.01      77.0   2.0    1009.0
# 1       9.0    184.0       AA1023  65.01      77.0   2.0    1009.0
# 2      74.0     98.0       AA1040  65.01      77.0   2.0    1009.0
# 3     -30.0     95.0       AA2525  65.01      77.0   2.0    1009.0
# 4      58.0    200.0       AA2576  47.59      81.0   3.0    1014.0
#
#      Description
# 0  broken clouds
# 1  broken clouds
# 2  broken clouds
# 3  broken clouds
# 4            fog

# %%
df['DepTime'] = pd.to_datetime(df['DepTime'],format= '%H%M%S' )

# %%
df['SchedDep'] = pd.to_datetime(df['SchedDep'],format= '%H%M%S' )

# %%
df['Delay_min'] = (df['DepTime'] - df['SchedDep']).dt.seconds/60

# %%
df.head(5)
# Out:
#    Month  DayofMonth  Hour Origin Dest            SchedDep  \
# 0      1           1    22    DFW  MIA 1900-01-01 21:20:00
# 1      1           1    22    DFW  LAX 1900-01-01 22:10:00
# 2      1           1    22    DFW  ORD 1900-01-01 21:30:00
# 3      1           1    22    DFW  ORD 1900-01-01 22:15:00
# 4      1           1    18    LAX  ORD 1900-01-01 17:50:00
#
#               DepTime  DepDelay  ArrTime  ArrDelay  AirTime FlightNumber  \
# 0 1900-01-01 22:04:00      84.0    139.0      73.0    136.0       AA2329
# 1 1900-01-01 22:16:00       6.0   2353.0       9.0    184.0       AA1023
# 2 1900-01-01 22:20:00      90.0     19.0      74.0     98.0       AA1040
# 3 1900-01-01 22:08:00      -7.0   2400.0     -30.0     95.0       AA2525
# 4 1900-01-01 18:37:00      87.0     21.0      58.0    200.0       AA2576
#
#     Temp  Humidity  Wind  Pressure    Description  Delay_min
# 0  65.01      77.0   2.0    1009.0  broken clouds       44.0
# 1  65.01      77.0   2.0    1009.0  broken clouds        6.0
# 2  65.01      77.0   2.0    1009.0  broken clouds       50.0
# 3  65.01      77.0   2.0    1009.0  broken clouds       -7.0
# 4  47.59      81.0   3.0    1014.0            fog       47.0

# %%
import numpy as np
df['Delay_min'] = np.where(df['Delay_min'] > 1400,df['DepDelay'], df['Delay_min'])

# %% [markdown]
# The code above calculates for the flights that departed ahead of schedule

# %%
df.head(5)
# Out:
#    Month  DayofMonth  Hour Origin Dest            SchedDep  \
# 0      1           1    22    DFW  MIA 1900-01-01 21:20:00
# 1      1           1    22    DFW  LAX 1900-01-01 22:10:00
# 2      1           1    22    DFW  ORD 1900-01-01 21:30:00
# 3      1           1    22    DFW  ORD 1900-01-01 22:15:00
# 4      1           1    18    LAX  ORD 1900-01-01 17:50:00
#
#               DepTime  DepDelay  ArrTime  ArrDelay  AirTime FlightNumber  \
# 0 1900-01-01 22:04:00      84.0    139.0      73.0    136.0       AA2329
# 1 1900-01-01 22:16:00       6.0   2353.0       9.0    184.0       AA1023
# 2 1900-01-01 22:20:00      90.0     19.0      74.0     98.0       AA1040
# 3 1900-01-01 22:08:00      -7.0   2400.0     -30.0     95.0       AA2525
# 4 1900-01-01 18:37:00      87.0     21.0      58.0    200.0       AA2576
#
#     Temp  Humidity  Wind  Pressure    Description  Delay_min
# 0  65.01      77.0   2.0    1009.0  broken clouds       44.0
# 1  65.01      77.0   2.0    1009.0  broken clouds        6.0
# 2  65.01      77.0   2.0    1009.0  broken clouds       50.0
# 3  65.01      77.0   2.0    1009.0  broken clouds       -7.0
# 4  47.59      81.0   3.0    1014.0            fog       47.0

# %% [markdown]
# Our overall datapoints to work with after dropping all the data we do not need is 66,180 datapoints

# %%
df.to_csv('final_flight_data', encoding = 'utf-8', index = False)
