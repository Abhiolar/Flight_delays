# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
reg_data = pd.read_csv('cleaned_data')

# %%
reg_data.head()
# Out:
#                         Date        Summary Precip_Type  Temperature  \
# 0  2006-04-01 00:00:00+00:00  Partly Cloudy        rain     9.472222
# 1  2006-04-01 01:00:00+00:00  Partly Cloudy        rain     9.355556
# 2  2006-04-01 02:00:00+00:00  Mostly Cloudy        rain     9.377778
# 3  2006-04-01 03:00:00+00:00  Partly Cloudy        rain     8.288889
# 4  2006-04-01 04:00:00+00:00  Mostly Cloudy        rain     8.755556
#
#    Apparent_temperature  Humidity  Wind_speed  Wind_Bearing  Visibility  \
# 0              7.388889      0.89     14.1197         251.0     15.8263
# 1              7.227778      0.86     14.2646         259.0     15.8263
# 2              9.377778      0.89      3.9284         204.0     14.9569
# 3              5.944444      0.83     14.1036         269.0     15.8263
# 4              6.977778      0.83     11.0446         259.0     15.8263
#
#    Pressure                      Daily_Summary  Precipitation_cat
# ...

# %%
reg_data.hist(figsize=(18,10) );

# %% [markdown]
# #### We see lot of skewness and kurtosis in some of the variables including Humidity, Wind-bearing, Wind speed. Some variables have outliers at extreme tails such as Wind speed the target variables looks good with some outliers in the right and left tail

# %% [markdown]
# ## CHECKING THE LINEARITY OF THE FEATURES OF THE DATA SET WITH THE TARGET VARIABLE

# %%
for column in ['Temperature', 'Humidity', 'Wind_speed', 'Wind_Bearing', 'Visibility', 'Pressure']:
    plt.scatter(reg_data[column], reg_data.Apparent_temperature, label=column)
    plt.legend()
    plt.show()
